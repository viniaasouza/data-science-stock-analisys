# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\vinia\anaconda3\lib\site-packages (0.2.65)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\vinia\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\vinia\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\vinia\anaconda3\lib\site-packages (from yfinance) (2.32.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\vinia\anaconda3\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\vinia\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\vinia\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\vinia\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\vinia\anaconda3\lib\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\vinia\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\vinia\anaconda3\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\vinia\anaconda3\lib\site-packages (from yfinance) (3.20.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\vinia\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\vinia\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\vinia\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.16.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\vinia\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vinia\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vinia\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vinia\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vinia\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vinia\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: pycparser in c:\users\vinia\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\vinia\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bbas = yf.Ticker("BBAS3.SA")

# %%
bbas.history(period="max")
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2000-01-03 00:00:00-02:00   0.514301   0.524097   0.502056   0.502056
# 2000-01-04 00:00:00-02:00   0.502056   0.503281   0.478177   0.478177
# 2000-01-05 00:00:00-02:00   0.477565   0.483687   0.460422   0.483075
# 2000-01-06 00:00:00-02:00   0.483076   0.489811   0.477565   0.489811
# 2000-01-07 00:00:00-02:00   0.489810   0.489810   0.478790   0.478790
# ...                              ...        ...        ...        ...
# 2025-08-18 00:00:00-03:00  20.570000  21.180000  20.150000  21.070000
# 2025-08-19 00:00:00-03:00  20.799999  20.930000  19.690001  19.799999
# 2025-08-20 00:00:00-03:00  19.770000  20.030001  19.530001  19.860001
# 2025-08-21 00:00:00-03:00  19.670000  19.799999  19.459999  19.690001
# 2025-08-22 00:00:00-03:00  19.690001  20.700001  19.620001  20.500000
#
#                              Volume  Dividends  Stock Splits
# Date
# 2000-01-03 00:00:00-02:00   1029600        0.0           0.0
# 2000-01-04 00:00:00-02:00    628200        0.0           0.0
# 2000-01-05 00:00:00-02:00    957600        0.0           0.0
# 2000-01-06 00:00:00-02:00    410400        0.0           0.0
# 2000-01-07 00:00:00-02:00    788400        0.0           0.0
# ...                             ...        ...           ...
# 2025-08-18 00:00:00-03:00  59254100        0.0           0.0
# 2025-08-19 00:00:00-03:00  58349400        0.0           0.0
# 2025-08-20 00:00:00-03:00  38402300        0.0           0.0
# 2025-08-21 00:00:00-03:00  34799500        0.0           0.0
# 2025-08-22 00:00:00-03:00  38192400        0.0           0.0
#
# [6438 rows x 7 columns]

# %%
bbas.history(period="max")["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bbas.info
# Out:
# {'address1': 'EdifIcio Banco do Brasil',
#  'address2': 'Quadra 5, Lote B Setor de Autarquias Norte',
#  'city': 'Brasília',
#  'state': 'DF',
#  'zip': '70040-911',
#  'country': 'Brazil',
#  'phone': '55 61 4004 0001',
#  'website': 'https://www.bb.com.br',
#  'industry': 'Banks - Regional',
#  'industryKey': 'banks-regional',
#  'industryDisp': 'Banks - Regional',
#  'sector': 'Financial Services',
#  'sectorKey': 'financial-services',
#  'sectorDisp': 'Financial Services',
#  'longBusinessSummary': "Banco do Brasil S.A., together with its subsidiaries, provides banking products and services for individuals, companies, and public sectors in Brazil and internationally. The company's Banking segment offers various products and services, including deposits, loans, and other services to retail, wholesale, and public sectors. This segment also engages in the business with micro-entrepreneurs and low-income population undertaken through banking correspondents. Its Investments segment engages in the domestic capital markets; intermediation and distribution of debts in the primary and secondary markets; and provision of equity investments and financial services. The company's Fund Management segment is involved in the purchase, sale, and custody of securities and portfolio management; and management of investment funds and clubs. Its Insurance, Pension and Capitalization segment provides life, property, and automobile insurance products, as well as private pension and capitalization plans. The company's Payments Method segment provides funding, transmission, processing, and settlement services for electronic transactions. Its Other segment engages in the provision of credit recovery and consortium management services. This segment is also involved in developing, manufacturing, selling, leasing, and integrating of digital electronic equipment and systems, peripherals, programs, inputs, and computing supplies. The company was incorporated in 1808 and is headquartered in Brasília, Brazil.",
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Ms. Tarciana Paula Gomes Medeiros',
#    'age': 46,
#    'title': 'CEO, Member of Executive Board & Director',
#    'yearBorn': 1978,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Marco Geovanne Tobias da Silva',
#    'title': 'CFO, Investor Relations Director & Member of Executive Board',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Luiz Gustavo Braz Lage',
#    'title': 'Chief Agribusiness Officer & Family Farming Officer and Member of Executive Board',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Carla  Nesi',
#    'age': 53,
#    'title': 'Chief Retail Business Officer & Member of Executive Board',
#    'yearBorn': 1971,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Francisco Augusto Lassalvia Gerson',
#    'age': 45,
#    'title': 'Chief Wholesale Officer & Member of Executive Board',
#    'yearBorn': 1979,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Felipe Guimaraes Geissler Prince',
#    'title': 'Chief Internal Controls & Risk Mgmt. Officer and Member of Executive Board',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Ana Cristina Rosa Garcia',
#    'title': 'Chief Corporate Officer & Member of Executive Board',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jose Ricardo Sasseron',
#    'title': 'Chief Government Business & Corporate Sustainability Officer and Member of Executive Board',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Marisa Reghini Ferreira Mattos',
#    'title': 'Chief Technology & Digital Business Officer and Member of Executive Board',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Neudson Peres de Freitas',
#    'title': 'Operations Officer',
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 2,
#  'boardRisk': 7,
#  'compensationRisk': 3,
#  'shareHolderRightsRisk': 4,
#  'overallRisk': 5,
#  'governanceEpochDate': 1754006400,
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 19.69,
#  'open': 0.0,
#  'dayLow': 0.0,
#  'dayHigh': 0.0,
#  'regularMarketPreviousClose': 19.69,
#  'regularMarketOpen': 0.0,
#  'regularMarketDayLow': 0.0,
#  'regularMarketDayHigh': 0.0,
#  'dividendRate': 0.36,
#  'dividendYield': 1.76,
#  'exDividendDate': 1748908800,
#  'payoutRatio': 0.4378,
#  'fiveYearAvgDividendYield': 5.18,
#  'beta': 0.308,
#  'trailingPE': 7.3741007,
#  'forwardPE': 2.9710145,
#  'volume': 0,
#  'regularMarketVolume': 0,
#  'averageVolume': 37703535,
#  'averageVolume10days': 51326190,
#  'averageDailyVolume10Day': 51326190,
#  'bid': 20.39,
#  'ask': 20.6,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 117021990912,
#  'fiftyTwoWeekLow': 0.0,
#  'fiftyTwoWeekHigh': 30.04,
#  'priceToSalesTrailing12Months': 1.4079685,
#  'fiftyDayAverage': 20.5808,
#  'twoHundredDayAverage': 24.932,
#  'trailingAnnualDividendRate': 1.898,
#  'trailingAnnualDividendYield': 0.09639411,
#  'currency': 'BRL',
#  'tradeable': False,
#  'enterpriseValue': 861594189824,
#  'profitMargins': 0.3,
#  'floatShares': 2585077760,
#  'sharesOutstanding': 5708389888,
#  'heldPercentInsiders': 0.5,
#  'heldPercentInstitutions': 0.24113001,
#  'impliedSharesOutstanding': 5708389888,
#  'bookValue': 30.987,
#  'priceToBook': 0.66156775,
#  'lastFiscalYearEnd': 1735603200,
#  'nextFiscalYearEnd': 1767139200,
#  'mostRecentQuarter': 1751241600,
#  'earningsQuarterlyGrowth': -0.68,
#  'netIncomeToCommon': 24934297600,
#  'trailingEps': 2.78,
#  'forwardEps': 6.9,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1713225600,
#  'enterpriseToRevenue': 10.366,
#  '52WeekChange': -0.2763855,
#  'SandP52WeekChange': 0.1513431,
#  'lastDividendValue': 0.090447,
#  'lastDividendDate': 1748908800,
#  'quoteType': 'EQUITY',
#  'currentPrice': 20.5,
#  'targetHighPrice': 39.0,
#  'targetLowPrice': 20.0,
#  'targetMeanPrice': 26.78462,
#  'targetMedianPrice': 24.0,
#  'recommendationMean': 2.69231,
#  'recommendationKey': 'hold',
#  'numberOfAnalystOpinions': 13,
#  'totalCash': 328218738688,
#  'totalCashPerShare': 57.497,
#  'totalDebt': 1068331958272,
#  'totalRevenue': 83114065920,
#  'revenuePerShare': 14.56,
#  'returnOnAssets': 0.01194,
#  'returnOnEquity': 0.15581,
#  'grossProfits': 82263515136,
#  'operatingCashflow': 35580182528,
#  'earningsGrowth': -0.68,
#  'revenueGrowth': -0.308,
#  'grossMargins': 0.0,
#  'ebitdaMargins': 0.0,
#  'operatingMargins': 0.23688,
#  'financialCurrency': 'BRL',
#  'symbol': 'BBAS3.SA',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': False,
#  'customPriceAlertConfidence': 'LOW',
#  'marketState': 'PREPRE',
#  'regularMarketChange': 0.80999947,
#  'regularMarketDayRange': '0.0 - 0.0',
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 946900800000,
#  'fullExchangeName': 'São Paulo',
#  'averageDailyVolume3Month': 37703535,
#  'fiftyTwoWeekLowChange': 20.5,
#  'fiftyTwoWeekRange': '0.0 - 30.04',
#  'fiftyTwoWeekHighChange': -9.540001,
#  'fiftyTwoWeekHighChangePercent': -0.3175766,
#  'fiftyTwoWeekChangePercent': -27.638548,
#  'earningsTimestamp': 1755201600,
#  'earningsTimestampStart': 1762977600,
#  'earningsTimestampEnd': 1762977600,
#  'earningsCallTimestampStart': 1763031540,
#  'earningsCallTimestampEnd': 1763031540,
#  'isEarningsDateEstimate': False,
#  'epsTrailingTwelveMonths': 2.78,
#  'epsForward': 6.9,
#  'epsCurrentYear': 3.87683,
#  'priceEpsCurrentYear': 5.287825,
#  'fiftyDayAverageChange': -0.0807991,
#  'fiftyDayAverageChangePercent': -0.003925946,
#  'twoHundredDayAverageChange': -4.431999,
#  'twoHundredDayAverageChangePercent': -0.17776349,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 15,
#  'averageAnalystRating': '2.7 - Hold',
#  'cryptoTradeable': False,
#  'regularMarketChangePercent': 4.1137605,
#  'regularMarketPrice': 20.5,
#  'shortName': 'BRASIL      ON      NM',
#  'longName': 'Banco do Brasil S.A.',
#  'corporateActions': [],
#  'regularMarketTime': 1755893264,
#  'exchange': 'SAO',
#  'messageBoardId': 'finmb_874155',
#  'exchangeTimezoneName': 'America/Sao_Paulo',
#  'exchangeTimezoneShortName': 'BRT',
#  'gmtOffSetMilliseconds': -10800000,
#  'market': 'br_market',
#  'esgPopulated': False,
#  'trailingPegRatio': None}

# %%
bbas.financials
#show major holders
bbas.major_holders

#show bnalance holders
bbas.institutional_holders

#show caashflow
bbas.cashflow
bbas.quarterly_cashflow

#show earnings
bbas.earnings
bbas.quarterly_earnings
# Out:
# C:\Users\vinia\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1057: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
# C:\Users\vinia\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1081: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
# C:\Users\vinia\anaconda3\Lib\site-packages\yfinance\scrapers\fundamentals.py:36: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)

# %%
tickers = yf.Tickers('PETR4.SA ABEV3.SA AMER3.SA')

# %%
tickers.tickers
# Out:
# {'PETR4.SA': yfinance.Ticker object <PETR4.SA>,
#  'ABEV3.SA': yfinance.Ticker object <ABEV3.SA>,
#  'AMER3.SA': yfinance.Ticker object <AMER3.SA>}

# %%
tickers.tickers["PETR4.SA"].balance_sheet
# Out:
#                                                     2024-12-31    2023-12-31  \
# Treasury Shares Number                            1.557642e+08  1.043597e+08
# Preferred Shares Number                                    NaN           NaN
# Ordinary Shares Number                            1.288873e+10  1.294014e+10
# Share Issued                                      1.304450e+10  1.304450e+10
# Net Debt                                          1.989100e+10  1.607400e+10
# ...                                                        ...           ...
# Cash Cash Equivalents And Short Term Investments  7.534000e+09  1.554600e+10
# Other Short Term Investments                      4.263000e+09  2.819000e+09
# Cash And Cash Equivalents                         3.271000e+09  1.272700e+10
# Cash Equivalents                                  3.135000e+09  1.262400e+10
# Cash Financial                                    1.360000e+08  1.030000e+08
#
#                                                     2022-12-31    2021-12-31  \
# Treasury Shares Number                            2.956690e+05  2.956690e+05
# Preferred Shares Number                                    NaN  5.601970e+09
# Ordinary Shares Number                            1.304420e+10  1.304420e+10
# Share Issued                                      1.304450e+10  1.304450e+10
# Net Debt                                          2.195800e+10  2.523300e+10
# ...                                                        ...           ...
# Cash Cash Equivalents And Short Term Investments  1.076900e+10  1.111700e+10
# Other Short Term Investments                      2.773000e+09  6.500000e+08
# Cash And Cash Equivalents                         7.996000e+09  1.046700e+10
# Cash Equivalents                                  7.780000e+09  1.016800e+10
# Cash Financial                                    2.160000e+08  2.990000e+08
#
#                                                   2020-12-31
# Treasury Shares Number                                   NaN
# Preferred Shares Number                                  NaN
# Ordinary Shares Number                                   NaN
# Share Issued                                             NaN
# Net Debt                                                 NaN
# ...                                                      ...
# Cash Cash Equivalents And Short Term Investments         NaN
# Other Short Term Investments                             NaN
# Cash And Cash Equivalents                                NaN
# Cash Equivalents                                         NaN
# Cash Financial                                           NaN
#
# [85 rows x 5 columns]

# %%
df_ibov = pd.read_csv("ibovdia_09-08-22.csv")
df_ibov
# Out:
#    Código          Ação        Tipo  Qtde. Teórica Part. (%)
# 0   RRRP3  3R PETROLEUM  ON      NM    200.372.163     0,341
# 1   ALPA4    ALPARGATAS  PN      N1    201.257.220     0,193
# 2   ABEV3     AMBEV S/A          ON  4.380.195.841     3,214
# 3   AMER3    AMERICANAS  ON      NM    596.875.824     0,421
# 4   ASAI3         ASSAI  ON      NM    794.531.367     0,682
# ..    ...           ...         ...            ...       ...
# 85  VALE3          VALE  ON      NM  3.768.748.489    12,817
# 86  VIIA3           VIA  ON      NM  1.596.295.753     0,231
# 87  VBBR3         VIBRA  ON      NM  1.131.883.365     1,016
# 88  WEGE3           WEG  ON      NM  1.484.859.030     2,189
# 89  YDUQ3    YDUQS PART  ON      NM    300.833.122     0,231
#
# [90 rows x 5 columns]

# %% [markdown]
# 1. Vamos analisar o histórico das 10 ações com maior participacão na bolsa. Encontre estes ativos no DataFrame df_ibov e carregue-os em um objeto Tickers do módulo do Yahoo.
# 2. Crie um dicionário que conterá como chaves os tickers de cada ativo (PETR4.SA, por exemplo) e como valores um DataFrame contendo os dados históricos de cada
# 3. Combine todos os dados em um único DataFrame, utilizando o preço de fechamento de cada ativo.
# 4. Qual a primeira data na qual todos os ativos estudados já estavam na bolsa?
# 5. Crie um DataFrame adicional para representar a variação percentual diária de cada ativo
# 6. Quais foram as datas na qual cada ativo apresentou sua pior oscilação? Apresente também a variação percentual.
# 7. Analisando esta série temporal, você conseguira estimar avaliar se existe uma maior probabilidade maior dos ativos performarem bem logo após um dia de queda?
# 8. Seguindo a lógica da questão anterior, avalie como em média se comportam as ações no pregão seguinte a quedas maiores que 1%. De posse destes dados, você acredita que seria uma boa estratégia de investimento comprar ações que cairam no dia anterior?
# 9. De tempos em tempos, empresas podem distribuir lucro aos acionistas na forma de dividendos. Podemos obter o histórico de pagamentos de dividendos usando a yfinance. Um indicador muito utilizado no mercado é o Dividend Yield (DY), que é calculado somando-se o total pago de dividendos no ano e dividindo pela cotação da ação. Calcule o DY anual de cada ativo.
# 10. Avalie o desempenho de uma estratégia de investimento que monta uma carteira de ações ano a ano com as 3 maiores pagadoras de dividendo do ano anterior. Compare o desempenho dela com o desempenho de uma carteira global.

# %%
df_ibov["Part.(%)"] = df_ibov["Part. (%)"].apply(lambda x: float(x.replace(",",".")))

# %%
#questão 1
acoes = df_ibov.sort_values("Part. (%)").tail(10)["Código"].values

acoes
# Out:
# array(['WEGE3', 'RENT3', 'ELET3', 'BBAS3', 'ABEV3', 'B3SA3', 'BBDC4',
#        'PETR3', 'ITUB4', 'PETR4'], dtype=object)

# %%
" ".join(acoes)
[i + ".SA" for i in acoes]
# Out:
# ['WEGE3.SA',
#  'RENT3.SA',
#  'ELET3.SA',
#  'BBAS3.SA',
#  'ABEV3.SA',
#  'B3SA3.SA',
#  'BBDC4.SA',
#  'PETR3.SA',
#  'ITUB4.SA',
#  'PETR4.SA']

# %%
tickers = yf.Tickers(" ".join([i + ".SA" for i in acoes]))
tickers.tickers
# Out:
# {'WEGE3.SA': yfinance.Ticker object <WEGE3.SA>,
#  'RENT3.SA': yfinance.Ticker object <RENT3.SA>,
#  'ELET3.SA': yfinance.Ticker object <ELET3.SA>,
#  'BBAS3.SA': yfinance.Ticker object <BBAS3.SA>,
#  'ABEV3.SA': yfinance.Ticker object <ABEV3.SA>,
#  'B3SA3.SA': yfinance.Ticker object <B3SA3.SA>,
#  'BBDC4.SA': yfinance.Ticker object <BBDC4.SA>,
#  'PETR3.SA': yfinance.Ticker object <PETR3.SA>,
#  'ITUB4.SA': yfinance.Ticker object <ITUB4.SA>,
#  'PETR4.SA': yfinance.Ticker object <PETR4.SA>}

# %% [markdown]
# fim da questão 1

# %%
#questão 2
dict_data = {}

for ticker in tickers.tickers.keys():
    print("Baixando: {}".format(tickers))
    dict_data[ticker] = tickers.tickers[ticker].history(period="max")
# Out:
# Baixando: yfinance.Tickers object <WEGE3.SA,RENT3.SA,ELET3.SA,BBAS3.SA,ABEV3.SA,B3SA3.SA,BBDC4.SA,PETR3.SA,ITUB4.SA,PETR4.SA>
# Baixando: yfinance.Tickers object <WEGE3.SA,RENT3.SA,ELET3.SA,BBAS3.SA,ABEV3.SA,B3SA3.SA,BBDC4.SA,PETR3.SA,ITUB4.SA,PETR4.SA>
# Baixando: yfinance.Tickers object <WEGE3.SA,RENT3.SA,ELET3.SA,BBAS3.SA,ABEV3.SA,B3SA3.SA,BBDC4.SA,PETR3.SA,ITUB4.SA,PETR4.SA>
# Baixando: yfinance.Tickers object <WEGE3.SA,RENT3.SA,ELET3.SA,BBAS3.SA,ABEV3.SA,B3SA3.SA,BBDC4.SA,PETR3.SA,ITUB4.SA,PETR4.SA>
# Baixando: yfinance.Tickers object <WEGE3.SA,RENT3.SA,ELET3.SA,BBAS3.SA,ABEV3.SA,B3SA3.SA,BBDC4.SA,PETR3.SA,ITUB4.SA,PETR4.SA>
# Baixando: yfinance.Tickers object <WEGE3.SA,RENT3.SA,ELET3.SA,BBAS3.SA,ABEV3.SA,B3SA3.SA,BBDC4.SA,PETR3.SA,ITUB4.SA,PETR4.SA>
# Baixando: yfinance.Tickers object <WEGE3.SA,RENT3.SA,ELET3.SA,BBAS3.SA,ABEV3.SA,B3SA3.SA,BBDC4.SA,PETR3.SA,ITUB4.SA,PETR4.SA>
# Baixando: yfinance.Tickers object <WEGE3.SA,RENT3.SA,ELET3.SA,BBAS3.SA,ABEV3.SA,B3SA3.SA,BBDC4.SA,PETR3.SA,ITUB4.SA,PETR4.SA>
# Baixando: yfinance.Tickers object <WEGE3.SA,RENT3.SA,ELET3.SA,BBAS3.SA,ABEV3.SA,B3SA3.SA,BBDC4.SA,PETR3.SA,ITUB4.SA,PETR4.SA>
# Baixando: yfinance.Tickers object <WEGE3.SA,RENT3.SA,ELET3.SA,BBAS3.SA,ABEV3.SA,B3SA3.SA,BBDC4.SA,PETR3.SA,ITUB4.SA,PETR4.SA>

# %%
dict_data["ITUB4.SA"]
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2000-12-21 00:00:00-02:00   1.323419   1.404752   1.323264   1.391598
# 2000-12-22 00:00:00-02:00   1.377588   1.377588   1.323108   1.331280
# 2000-12-25 00:00:00-02:00   1.331280   1.331280   1.331280   1.331280
# 2000-12-26 00:00:00-02:00   1.323963   1.332446   1.311432   1.330890
# 2000-12-27 00:00:00-02:00   1.354239   1.376031   1.330890   1.376031
# ...                              ...        ...        ...        ...
# 2025-08-18 00:00:00-03:00  37.238139  37.693715  37.149005  37.396599
# 2025-08-19 00:00:00-03:00  36.910000  36.919998  35.889999  36.310001
# 2025-08-20 00:00:00-03:00  36.270000  36.529999  36.049999  36.330002
# 2025-08-21 00:00:00-03:00  36.049999  36.430000  35.990002  36.369999
# 2025-08-22 00:00:00-03:00  36.500000  37.419998  36.389999  37.389999
#
#                              Volume  Dividends  Stock Splits
# Date
# 2000-12-21 00:00:00-02:00     81646     0.0000           0.0
# 2000-12-22 00:00:00-02:00     25643     0.0000           0.0
# 2000-12-25 00:00:00-02:00         0     0.0000           0.0
# 2000-12-26 00:00:00-02:00      8636     0.0000           0.0
# 2000-12-27 00:00:00-02:00     29695     0.0000           0.0
# ...                             ...        ...           ...
# 2025-08-18 00:00:00-03:00  21027800     0.0000           0.0
# 2025-08-19 00:00:00-03:00  39629100     0.3634           0.0
# 2025-08-20 00:00:00-03:00  16402800     0.0000           0.0
# 2025-08-21 00:00:00-03:00  15677300     0.0000           0.0
# 2025-08-22 00:00:00-03:00  31672900     0.0000           0.0
#
# [6185 rows x 7 columns]

# %% [markdown]
# FIM DA QUESTÃO 2

# %%
#QUESTÃO 3
df_data = pd.DataFrame()

for ticker in dict_data.keys():
    df_aux = dict_data[ticker].rename(columns={"Close": ticker})
    df_data = df_data.join(df_aux[ticker], how="outer")

# %%
df_data
# Out:
#                             WEGE3.SA   RENT3.SA   ELET3.SA   BBAS3.SA  \
# Date
# 2000-01-03 00:00:00-02:00   0.117940        NaN   9.174127   0.497318
# 2000-01-04 00:00:00-02:00   0.113801        NaN   8.730594   0.473666
# 2000-01-05 00:00:00-02:00   0.113801        NaN   9.080750   0.478518
# 2000-01-06 00:00:00-02:00   0.103455        NaN   8.870656   0.485189
# 2000-01-07 00:00:00-02:00   0.103455        NaN   9.010717   0.474272
# ...                              ...        ...        ...        ...
# 2025-08-18 00:00:00-03:00  36.410000  34.880001  42.290001  21.070000
# 2025-08-19 00:00:00-03:00  35.599998  33.799999  41.570000  19.799999
# 2025-08-20 00:00:00-03:00  36.070000  33.240002  42.119999  19.860001
# 2025-08-21 00:00:00-03:00  35.910000  32.700001  42.389999  19.690001
# 2025-08-22 00:00:00-03:00  37.500000  34.619999  42.680000  20.500000
#
#                             ABEV3.SA  B3SA3.SA   BBDC4.SA   PETR3.SA  \
# Date
# 2000-01-03 00:00:00-02:00        NaN       NaN        NaN   1.244074
# 2000-01-04 00:00:00-02:00        NaN       NaN        NaN   1.174253
# 2000-01-05 00:00:00-02:00   0.271542       NaN        NaN   1.190121
# 2000-01-06 00:00:00-02:00   0.257777       NaN        NaN   1.180600
# 2000-01-07 00:00:00-02:00   0.257777       NaN        NaN   1.190121
# ...                              ...       ...        ...        ...
# 2025-08-18 00:00:00-03:00  12.070000     13.16  16.350000  32.183754
# 2025-08-19 00:00:00-03:00  12.070000     12.53  15.790000  31.743015
# 2025-08-20 00:00:00-03:00  12.100000     12.33  15.840000  32.007462
# 2025-08-21 00:00:00-03:00  12.060000     12.25  15.790000  31.978079
# 2025-08-22 00:00:00-03:00  12.210000     12.56  16.309999  33.020000
#
#                             ITUB4.SA   PETR4.SA
# Date
# 2000-01-03 00:00:00-02:00        NaN   1.309279
# 2000-01-04 00:00:00-02:00        NaN   1.236851
# 2000-01-05 00:00:00-02:00        NaN   1.224371
# 2000-01-06 00:00:00-02:00        NaN   1.220136
# 2000-01-07 00:00:00-02:00        NaN   1.225709
# ...                              ...        ...
# 2025-08-18 00:00:00-03:00  37.396599  29.686525
# 2025-08-19 00:00:00-03:00  36.310001  29.373623
# 2025-08-20 00:00:00-03:00  36.330002  29.549629
# 2025-08-21 00:00:00-03:00  36.369999  29.618078
# 2025-08-22 00:00:00-03:00  37.389999  30.469999
#
# [6438 rows x 10 columns]

# %% [markdown]
# fim da questão 3

# %%
#questão 4
df_data.dropna().index[0]
#fim da questão 4
# Out:
# Timestamp('2008-01-02 00:00:00-0200', tz='America/Sao_Paulo')

# %%
df_ret = df_data / df_data.shift(1) - 1
#shift calcula matrix e retorno
df_ret
# Out:
#                            WEGE3.SA  RENT3.SA  ELET3.SA  BBAS3.SA  ABEV3.SA  \
# Date
# 2000-01-03 00:00:00-02:00       NaN       NaN       NaN       NaN       NaN
# 2000-01-04 00:00:00-02:00 -0.035093       NaN -0.048346 -0.047561       NaN
# 2000-01-05 00:00:00-02:00  0.000000       NaN  0.040107  0.010244       NaN
# 2000-01-06 00:00:00-02:00 -0.090910       NaN -0.023136  0.013942 -0.050691
# 2000-01-07 00:00:00-02:00  0.000000       NaN  0.015789 -0.022499  0.000000
# ...                             ...       ...       ...       ...       ...
# 2025-08-18 00:00:00-03:00  0.012232  0.019287 -0.004762  0.020339  0.002492
# 2025-08-19 00:00:00-03:00 -0.022247 -0.030963 -0.017025 -0.060275  0.000000
# 2025-08-20 00:00:00-03:00  0.013202 -0.016568  0.013231  0.003030  0.002486
# 2025-08-21 00:00:00-03:00 -0.004436 -0.016246  0.006410 -0.008560 -0.003306
# 2025-08-22 00:00:00-03:00  0.044277  0.058716  0.006841  0.041138  0.012438
#
#                            B3SA3.SA  BBDC4.SA  PETR3.SA  ITUB4.SA  PETR4.SA
# Date
# 2000-01-03 00:00:00-02:00       NaN       NaN       NaN       NaN       NaN
# 2000-01-04 00:00:00-02:00       NaN       NaN -0.056122       NaN -0.055319
# 2000-01-05 00:00:00-02:00       NaN       NaN  0.013513       NaN -0.010090
# 2000-01-06 00:00:00-02:00       NaN       NaN -0.008000       NaN -0.003458
# 2000-01-07 00:00:00-02:00       NaN       NaN  0.008065       NaN  0.004566
# ...                             ...       ...       ...       ...       ...
# 2025-08-18 00:00:00-03:00  0.000760  0.019963  0.007975  0.007202  0.006298
# 2025-08-19 00:00:00-03:00 -0.047872 -0.034251 -0.013694 -0.029056 -0.010540
# 2025-08-20 00:00:00-03:00 -0.015962  0.003167  0.008331  0.000551  0.005992
# 2025-08-21 00:00:00-03:00 -0.006488 -0.003157 -0.000918  0.001101  0.002316
# 2025-08-22 00:00:00-03:00  0.025306  0.032932  0.032582  0.028045  0.028764
#
# [6438 rows x 10 columns]

# %%
#questão 6
df_ret.idxmin()
# Out:
# WEGE3.SA   2020-03-16 00:00:00-03:00
# RENT3.SA   2020-03-16 00:00:00-03:00
# ELET3.SA   2010-02-01 00:00:00-02:00
# BBAS3.SA   2016-03-15 00:00:00-03:00
# ABEV3.SA   2005-04-04 00:00:00-03:00
# B3SA3.SA   2011-05-09 00:00:00-03:00
# BBDC4.SA   2009-05-29 00:00:00-03:00
# PETR3.SA   2020-03-09 00:00:00-03:00
# ITUB4.SA   2021-10-04 00:00:00-03:00
# PETR4.SA   2020-03-09 00:00:00-03:00
# dtype: datetime64[ns, America/Sao_Paulo]

# %%
#questão 7

df_ret[df_ret.shift(1) <0].mean()
# Out:
# WEGE3.SA    0.001143
# RENT3.SA    0.001160
# ELET3.SA   -0.000018
# BBAS3.SA    0.000390
# ABEV3.SA    0.001049
# B3SA3.SA    0.001162
# BBDC4.SA    0.000770
# PETR3.SA    0.000413
# ITUB4.SA    0.000452
# PETR4.SA    0.000560
# dtype: float64

# %%
df_ret[df_ret.shift(1) <0].std()
# Out:
# WEGE3.SA    0.021203
# RENT3.SA    0.027225
# ELET3.SA    0.030258
# BBAS3.SA    0.027453
# ABEV3.SA    0.018155
# B3SA3.SA    0.027931
# BBDC4.SA    0.024030
# PETR3.SA    0.028529
# ITUB4.SA    0.022473
# PETR4.SA    0.027953
# dtype: float64

# %%
df_study = df_ret[df_ret.shift(1) < 0]
fig, ax = plt.subplots()
sns.histplot(df_study, kde=True)

print("Média dos retornos" )
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].mean()*100))

print("desvio padrao" )
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].std()*100))
# Out:
# Média dos retornos
# WEGE3 - 0.11428330984304949
# RENT3 - 0.11602616689067172
# ELET3 - -0.0018492374900090831
# BBAS3 - 0.038992467350232006
# ABEV3 - 0.10492923062631956
# B3SA3 - 0.11623555703918807
# BBDC4 - 0.0770419137063233
# PETR3 - 0.041328695843611186
# ITUB4 - 0.04522401671020017
# PETR4 - 0.05595770886426063
# desvio padrao
# WEGE3 - 2.1202560305536635
# RENT3 - 2.7225069202985086
# ELET3 - 3.025848946833594
# BBAS3 - 2.7452512946314283
# ABEV3 - 1.8154687445735624
# B3SA3 - 2.7930818524553205
# BBDC4 - 2.4029570212025577
# PETR3 - 2.852883040268176
# ITUB4 - 2.247326126086314
# PETR4 - 2.795252033043459

# %%
#questão 8
df_study = df_ret[df_ret.shift(1) < 0.05]
fig, ax = plt.subplots()
sns.histplot(df_study, kde=True)

print("Média dos retornos" )
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].mean()*100))

print("desvio padrao" )
for acao in acoes:
    print('{} - {}'.format(acao, df_study[acao + '.SA'].std()*100))
# Out:
# Média dos retornos
# WEGE3 - 0.10427933978304352
# RENT3 - 0.11174045226406604
# ELET3 - 0.04355411201011121
# BBAS3 - 0.09116478506492658
# ABEV3 - 0.07224797102097459
# B3SA3 - 0.03854462280207007
# BBDC4 - 0.04256207699902806
# PETR3 - 0.07823546205136978
# ITUB4 - 0.07074778721069469
# PETR4 - 0.08268094349322098
# desvio padrao
# WEGE3 - 2.0371852806660757
# RENT3 - 2.616338321651029
# ELET3 - 2.9992520490514067
# BBAS3 - 2.5598734755120636
# ABEV3 - 1.794064778763527
# B3SA3 - 2.7967518045473394
# BBDC4 - 2.2723075912288255
# PETR3 - 2.629801554528138
# ITUB4 - 2.138942844153787
# PETR4 - 2.555443022326551

# %%
#desafio 9
tickers.tickers
# Out:
# {'WEGE3.SA': yfinance.Ticker object <WEGE3.SA>,
#  'RENT3.SA': yfinance.Ticker object <RENT3.SA>,
#  'ELET3.SA': yfinance.Ticker object <ELET3.SA>,
#  'BBAS3.SA': yfinance.Ticker object <BBAS3.SA>,
#  'ABEV3.SA': yfinance.Ticker object <ABEV3.SA>,
#  'B3SA3.SA': yfinance.Ticker object <B3SA3.SA>,
#  'BBDC4.SA': yfinance.Ticker object <BBDC4.SA>,
#  'PETR3.SA': yfinance.Ticker object <PETR3.SA>,
#  'ITUB4.SA': yfinance.Ticker object <ITUB4.SA>,
#  'PETR4.SA': yfinance.Ticker object <PETR4.SA>}

# %%
#questão 9
df_dividends = pd.DataFrame()

for ticker in tickers.tickers.keys():
    df_dividends_aux = tickers.tickers[ticker].dividends.to_frame().rename(columns={"Dividends": ticker})
    df_dividends = df_dividends.join(df_dividends_aux, how="outer")

# %%
df_dividends['year'] = df_dividends.index.year
df_data['year'] = df_data.index.year

# %%
df_dividends_year = df_dividends.groupby('year').sum()
df_last_price = df_data.dropna().groupby('year').last()

# %%
df_last_price
# Out:
#        WEGE3.SA   RENT3.SA   ELET3.SA   BBAS3.SA   ABEV3.SA   B3SA3.SA  \
# year
# 2008   1.320007   1.482222  12.288288   2.691826   1.807674   3.539184
# 2009   1.995888   3.969557  18.269356   5.487465   3.311756   7.279251
# 2010   2.410198   5.737902  12.337663   6.246754   4.852828   7.894168
# 2011   2.138810   5.533431   9.899628   4.969397   6.344872   2.037526
# 2012   3.151841   8.200098   3.512592   5.749468  10.072631   3.019351
# 2013   3.730504   7.952160   4.264305   6.059869  10.581897   2.484694
# 2014   4.866705   8.629544   4.451675   6.313284  10.292255   2.291858
# 2015   4.883018   6.160566   4.420974   4.325124  12.390629   2.714054
# 2016   5.192454   8.735623  17.507360   8.624776  11.799081   4.241295
# 2017   8.231408  18.000879  14.844032  10.077922  15.741494   5.978384
# 2018   7.923619  24.534462  18.597258  15.115757  11.748616   7.252054
# 2019  15.902871  41.471741  29.797989  18.085480  14.636387  11.866141
# 2020  35.031197  60.769257  30.139612  13.820485  12.593248  17.683077
# 2021  30.858217  47.068043  29.548252  11.071182  12.953865   9.962012
# 2022  36.675148  48.444107  37.983997  14.732934  12.840503  12.253055
# 2023  35.722931  59.588436  38.512787  25.130093  12.776534  13.915257
# 2024  51.985863  31.381266  32.106087  23.770781  11.526866  10.203959
# 2025  37.500000  34.619999  42.680000  20.500000  12.210000  12.560000
#
#        BBDC4.SA   PETR3.SA   ITUB4.SA   PETR4.SA
# year
# 2008   7.141419   7.444803   5.093296   5.414222
# 2009   6.580946  11.361464   8.341311   8.886903
# 2010   6.000097   8.487543   8.788943   6.757069
# 2011   5.852004   6.418207   7.758683   5.394392
# 2012   6.894597   5.536794   7.879157   4.925046
# 2013   6.460838   4.528560   8.606825   4.393323
# 2014   8.034266   2.816226  10.542597   2.756653
# 2015   5.633803   2.516689   9.277390   1.841433
# 2016   9.785972   4.974647  13.913088   4.086882
# 2017  13.060100   4.965837  18.166462   4.424936
# 2018  16.843710   7.531963  23.210266   6.502675
# 2019  20.022013   9.649531  25.293608   8.940452
# 2020  16.975531   8.788464  22.146671   8.395541
# 2021  13.808710  11.458251  15.191523  10.369354
# 2022  12.249010  17.070789  18.864878  14.303158
# 2023  14.947124  29.985451  26.846106  28.150272
# 2024  10.744984  36.686699  26.058231  33.523006
# 2025  16.309999  33.020000  37.389999  30.469999

# %%
# questão 10

df_ret_year = df_last_price / df_last_price.shift(1) - 1

# %%
((df_ret_year / 10).sum(axis=1) + 1).cumprod().plot()
# Out:
# <Axes: xlabel='year'>

# %%
df_yield
df_yield.iloc[0, :].nlargest(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[421], line 1
# ----> 1 df_yield.iloc[0, :].nlargest(3)
#
# NameError: name 'df_yield' is not defined
